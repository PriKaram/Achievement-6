# %% [markdown]
# ## Content List:
# 1.Importing libraries and dataframe
#
# 2.Checking descriptive stats
#
# 3.Data Wrangling: None Needed
#
# 4.Data Consistency Checks
#
#  -Missing Data: rows were deleted
#
#  -Mixed Data Type: None
#
#  -Duplicate data: rows were deleted
#
# 5.Exporting Data

# %%
# importing libraries
import pandas as pd
import numpy as np
import os

# %%
#importing dataframe
df = pd.read_csv(r'C:\Users\nikman\Desktop\kaggle data sets\Indicators of heart disease\2022\heart_2022_with_nans.csv')

# %%
#checking dataframe
df.head()
# Out:
#      State     Sex GeneralHealth  PhysicalHealthDays  MentalHealthDays  \
# 0  Alabama  Female     Very good                 0.0               0.0
# 1  Alabama  Female     Excellent                 0.0               0.0
# 2  Alabama  Female     Very good                 2.0               3.0
# 3  Alabama  Female     Excellent                 0.0               0.0
# 4  Alabama  Female          Fair                 2.0               0.0
#
#                                      LastCheckupTime PhysicalActivities  \
# 0  Within past year (anytime less than 12 months ...                 No
# 1                                                NaN                 No
# 2  Within past year (anytime less than 12 months ...                Yes
# 3  Within past year (anytime less than 12 months ...                Yes
# 4  Within past year (anytime less than 12 months ...                Yes
#
#    SleepHours RemovedTeeth HadHeartAttack  ... HeightInMeters  \
# ...

# %%
#checking dataframe dimensions
df.shape
# Out:
# (445132, 40)

# %%
#checking descriptive stats without scientific symbol
df.describe().apply(lambda x: x.apply('{0:.5f}'.format))
# Out:
#       PhysicalHealthDays MentalHealthDays    SleepHours HeightInMeters  \
# count       434205.00000     436065.00000  439679.00000   416480.00000
# mean             4.34792          4.38265       7.02298        1.70269
# std              8.68891          8.38747       1.50243        0.10718
# min              0.00000          0.00000       1.00000        0.91000
# 25%              0.00000          0.00000       6.00000        1.63000
# 50%              0.00000          0.00000       7.00000        1.70000
# 75%              3.00000          5.00000       8.00000        1.78000
# max             30.00000         30.00000      24.00000        2.41000
#
#       WeightInKilograms           BMI
# count      403054.00000  396326.00000
# mean           83.07447      28.52984
# std            21.44817       6.55489
# min            22.68000      12.02000
# 25%            68.04000      24.13000
# 50%            80.74000      27.44000
# 75%            95.25000      31.75000
# ...

# %%
#checking data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 445132 entries, 0 to 445131
# Data columns (total 40 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   State                      445132 non-null  object
#  1   Sex                        445132 non-null  object
#  2   GeneralHealth              443934 non-null  object
#  3   PhysicalHealthDays         434205 non-null  float64
#  4   MentalHealthDays           436065 non-null  float64
#  5   LastCheckupTime            436824 non-null  object
#  6   PhysicalActivities         444039 non-null  object
#  7   SleepHours                 439679 non-null  float64
#  8   RemovedTeeth               433772 non-null  object
#  9   HadHeartAttack             442067 non-null  object
#  10  HadAngina                  440727 non-null  object
#  11  HadStroke                  443575 non-null  object
#  12  HadAsthma                  443359 non-null  object
# ...

# %% [markdown]
# ## Checking for missing values

# %%
#checking for missing values
df.isnull().sum()
# Out:
# State                            0
# Sex                              0
# GeneralHealth                 1198
# PhysicalHealthDays           10927
# MentalHealthDays              9067
# LastCheckupTime               8308
# PhysicalActivities            1093
# SleepHours                    5453
# RemovedTeeth                 11360
# HadHeartAttack                3065
# HadAngina                     4405
# HadStroke                     1557
# HadAsthma                     1773
# HadSkinCancer                 3143
# HadCOPD                       2219
# HadDepressiveDisorder         2812
# HadKidneyDisease              1926
# HadArthritis                  2633
# HadDiabetes                   1087
# DeafOrHardOfHearing          20647
# BlindOrVisionDifficulty      21564
# DifficultyConcentrating      24240
# DifficultyWalking            24012
# DifficultyDressingBathing    23915
# DifficultyErrands            25656
# SmokerStatus                 35462
# ECigaretteUsage              35660
# ...

# %%
#dropping all missing values in place
df.dropna(inplace = True)

# %%
df.shape
# Out:
# (246022, 40)

# %%
#checking for missing values
df.isnull().sum()
# Out:
# State                        0
# Sex                          0
# GeneralHealth                0
# PhysicalHealthDays           0
# MentalHealthDays             0
# LastCheckupTime              0
# PhysicalActivities           0
# SleepHours                   0
# RemovedTeeth                 0
# HadHeartAttack               0
# HadAngina                    0
# HadStroke                    0
# HadAsthma                    0
# HadSkinCancer                0
# HadCOPD                      0
# HadDepressiveDisorder        0
# HadKidneyDisease             0
# HadArthritis                 0
# HadDiabetes                  0
# DeafOrHardOfHearing          0
# BlindOrVisionDifficulty      0
# DifficultyConcentrating      0
# DifficultyWalking            0
# DifficultyDressingBathing    0
# DifficultyErrands            0
# SmokerStatus                 0
# ECigaretteUsage              0
# ChestScan                    0
# RaceEthnicityCategory        0
# AgeCategory                  0
# ...

# %% [markdown]
# ## Checking for mixed data type

# %%
#checking for mixed data type
for col in df.columns.tolist():
  weird = (df[[col]].map(type) != df[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df[weird]) > 0:
    print (col)
else :
    print ("None of the columns have mix data")
# Out:
# None of the columns have mix data

# %% [markdown]
# ## Checking for duplicates

# %%
#looking for duplicates
df_dups = df[df.duplicated()]

# %%
df_dups
# Out:
#                State     Sex GeneralHealth  PhysicalHealthDays  \
# 11503        Arizona  Female     Excellent                 0.0
# 158614      Maryland  Female          Good                 0.0
# 160190      Maryland    Male     Excellent                 0.0
# 248581    New Jersey    Male          Good                 0.0
# 317690  Rhode Island  Female     Very good                 0.0
# 334780  South Dakota  Female          Fair                30.0
# 378773       Vermont  Female     Very good                 0.0
# 393885    Washington    Male     Excellent                 0.0
# 411025    Washington    Male     Very good                 0.0
#
#         MentalHealthDays                                    LastCheckupTime  \
# 11503                0.0  Within past year (anytime less than 12 months ...
# 158614               0.0  Within past year (anytime less than 12 months ...
# 160190               0.0  Within past year (anytime less than 12 months ...
# ...

# %%
df_no_dups = df.drop_duplicates()

# %%
df_no_dups
# Out:
#                  State     Sex GeneralHealth  PhysicalHealthDays  \
# 342            Alabama  Female     Very good                 4.0
# 343            Alabama    Male     Very good                 0.0
# 345            Alabama    Male     Very good                 0.0
# 346            Alabama  Female          Fair                 5.0
# 347            Alabama  Female          Good                 3.0
# ...                ...     ...           ...                 ...
# 445117  Virgin Islands    Male     Very good                 0.0
# 445123  Virgin Islands  Female          Fair                 0.0
# 445124  Virgin Islands    Male          Good                 0.0
# 445128  Virgin Islands  Female     Excellent                 2.0
# 445130  Virgin Islands    Male     Very good                 0.0
#
#         MentalHealthDays                                    LastCheckupTime  \
# 342                  0.0  Within past year (anytime less than 12 months ...
# ...

# %% [markdown]
# ## Dataframe descriptive stats

# %%
df_no_dups.describe()
# Out:
#        PhysicalHealthDays  MentalHealthDays     SleepHours  HeightInMeters  \
# count       246013.000000     246013.000000  246013.000000   246013.000000
# mean             4.119055          4.167292       7.021312        1.705150
# std              8.405803          8.102796       1.440698        0.106654
# min              0.000000          0.000000       1.000000        0.910000
# 25%              0.000000          0.000000       6.000000        1.630000
# 50%              0.000000          0.000000       7.000000        1.700000
# 75%              3.000000          4.000000       8.000000        1.780000
# max             30.000000         30.000000      24.000000        2.410000
#
#        WeightInKilograms            BMI
# count      246013.000000  246013.000000
# mean           83.615522      28.668258
# std            21.323232       6.514005
# min            28.120000      12.020000
# 25%            68.040000      24.270000
# 50%            81.650000      27.460000
# ...

# %% [markdown]
# ## Getting count of unique variables

# %%
df_no_dups.nunique()
# Out:
# State                          54
# Sex                             2
# GeneralHealth                   5
# PhysicalHealthDays             31
# MentalHealthDays               31
# LastCheckupTime                 4
# PhysicalActivities              2
# SleepHours                     23
# RemovedTeeth                    4
# HadHeartAttack                  2
# HadAngina                       2
# HadStroke                       2
# HadAsthma                       2
# HadSkinCancer                   2
# HadCOPD                         2
# HadDepressiveDisorder           2
# HadKidneyDisease                2
# HadArthritis                    2
# HadDiabetes                     4
# DeafOrHardOfHearing             2
# BlindOrVisionDifficulty         2
# DifficultyConcentrating         2
# DifficultyWalking               2
# DifficultyDressingBathing       2
# DifficultyErrands               2
# SmokerStatus                    4
# ECigaretteUsage                 4
# ...

# %% [markdown]
# ## Creating string path

# %%
path = r'C:\Users\nikman\Desktop\kaggle data sets\Indicators of heart disease\2022'

# %% [markdown]
# ## Exporting dataframe

# %%
df_no_dups.to_csv(os.path.join(path, 'Cleaned_heart_indicators data set','Cleaned_data.csv'))
